# %%
name="Abhishek"
age="18"
course="B.Tech AI/ML"
print(name)
print(age)
print(course)
# Out:
# Abhishek
# 18
# B.Tech AI/ML

# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects[0])
print(subjects[-1])
# Out:
# Python
# Data

# %%
# Personal Dict
myprofile = {
    "name": "AbhishekChaudhary",
    "age": 18,
    "course": "B.Tech AI/ML",
    "Topic": "Mathematics",
    "ConfiLevel": 9
}

print(myprofile["name"])
print(myprofile["Topic"])
# Out:
# AbhishekChaudhary
# Mathematics

# %%
n=-5
if n>0:
  print("Positive")
elif n<0:
  print("Negative")
else:
  print("Zero")
# Out:
# Negative

# %%
marks= [78,35,91,22,72]
for i in marks:
  if i>=76:
    print("Strong")
  elif i>=40:
    print("Average")
  else:
    print("Needs Improvement")
# Out:
# Strong
# Needs Improvement
# Strong
# Needs Improvement
# Average

# %%
students = [
    {"name": "Aarav", "study_hours": 6, "attendance": 85, "marks": 78},
    {"name": "Riya", "study_hours": 3, "attendance": 70, "marks": 55},
    {"name": "Kabir", "study_hours": 8, "attendance": 90, "marks": 88},
    {"name": "Meera", "study_hours": 2, "attendance": 60, "marks": 35}
]
for i in students:
  if i["marks"]>=75:
    print("Strong")
  elif i["attendance"]<75:
    print("Low Attendance")
  elif i["study_hours"]<4:
    print("Need more study time")
# Out:
# Strong
# Low Attendance
# Strong
# Low Attendance
